# %% [markdown]
# <a href="https://colab.research.google.com/github/lsmanoel/pythonLearningAndDeepLearning/blob/master/DlibAndOpenCV-FaceDetection/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Haar Cascade Face Recognition
# Hi... in this notes I will shown how to detect faces with different tools present in the Dlib and OpenCV packages.
# We will detect diferent faces and place a Bounding Box in each detected face. First we use Haar Cascade technique using only OpenCV package.
#
# The Bounding Box in OpenCV is defined by a reference pixel coordinate (the left top pixel of Box) and the width e hight of the Bounding Box.
#
# LEFT, TOP, WIDTH, HEIGHT.
#
# With this four data we can draw a Bounding Box on the analized image that indicate the detected face.
#
# The Haar Cascade technique consists of detecting the features Haar in the image. The exemple of Haar characteristics (the features Haar) is shown bellow:
# ![alt text](https://docs.opencv.org/3.0-beta/_images/haarfeatures.png)
# Each type of pattern in the analyzed image tends to have a similar amount of features Haar. Soon this technique uses this similarity to identify patterns in the image.
# The classification system is composed of a series cascade filter capturing characteristics. Similar to AND logic, for the image to be classified like ¨Detected Object¨, the different features Haar must be correlated with all filters (one filter to each features Haar): F1, F2, F3...
# ![alt text](http://3.bp.blogspot.com/-EiP9XkuzQFU/Vft_kUVaTwI/AAAAAAAADxE/recSE2ctlRY/s1600/2.png).
# These filters are trained with a dataset composed of positive and negative images. The positive images are the patterns that we wish detect and the negative images are the patterns which should not be detected.

# %% [markdown]
# Lets TRY... Save the image in your google driver and open this storage with code bellow.
#
# ![alt text](http://blogs.discovermagazine.com/neuroskeptic/files/2018/04/tom_cruise_lol.png)
#
# Save this image in your google drive and mount this storage in colab Files workspace:

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %% [markdown]
# You may download the "haarcascade_frontalface_default.xml" from:
# https://github.com/lsmanoel/pythonLearningAndDeepLearning/tree/master/DlibAndOpenCV-FaceDetection/resources
#
# This data have the features Haar result of a training with images of frontal faces.

# %%
import cv2
from matplotlib import pyplot as plt

frame = cv2.imread("gdrive/My Drive/Colab Notebooks/face_detection/photos/tom_cruise_lol.png")
image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

classifier= cv2.CascadeClassifier("gdrive/My Drive/Colab Notebooks/face_detection/resources/haarcascade_frontalface_default.xml")

grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detectedFaces = classifier.detectMultiScale(grayImage, scaleFactor=1.2, minSize=(50,50))

print("Detected Faces: ", len(detectedFaces))
print("Bounding Boxs:")
print("LEFT, TOP, WIDTH, HEIGHT:")
print(detectedFaces)

for (x, y, l, a) in detectedFaces:
    cv2.rectangle(image, (x, y), (x + l, y + a), (0, 255, 0), 2)

plt.imshow(image)
plt.show()
# Out:
# Detected Faces:  10
# Bounding Boxs:
# LEFT, TOP, WIDTH, HEIGHT:
# [[136  53 108 108]
#  [ 17  53 115 115]
#  [253  53 111 111]
#  [482  54 112 112]
#  [367  53 119 119]
#  [135 279 111 111]
#  [253 281 107 107]
#  [366 273 119 119]
#  [ 17 279 113 113]
#  [495 308  89  89]]

# %% [markdown]
# # Anti-Surveillance Camouflage:
#
# The patterns applied the paint is important: To the pixel-calculating machinations of facial recognition algorithms, they transformed the face into a mess of unremarkable pixels. In the computer’s vision, this camouflage caused a momentary burst of confusion.
#
# ![alt text](https://cdn.theatlantic.com/assets/media/img/2014/07/24/opener_v03_2/1920.jpg?1440086867)
#
#
# More about Anti-Surveillance Camouflage:
# [link text](https://www.theatlantic.com/technology/archive/2014/07/makeup/374929/)

# %%
import cv2
from matplotlib import pyplot as plt

frame1 = cv2.imread("gdrive/My Drive/Colab Notebooks/face_detection/photos/NOAnti-SurveillanceCamouflage.jpeg")
NOCamouflage = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

frame2 = cv2.imread("gdrive/My Drive/Colab Notebooks/face_detection/photos/Anti-SurveillanceCamouflage.jpg")
Camouflage  = cv2.cvtColor(frame2, cv2.COLOR_BGR2RGB)

classifier= cv2.CascadeClassifier("gdrive/My Drive/Colab Notebooks/face_detection/resources/haarcascade_frontalface_default.xml")

grayImage1 = cv2.cvtColor(NOCamouflage, cv2.COLOR_BGR2GRAY)
detectedFaces = classifier.detectMultiScale(grayImage1, scaleFactor=1.2, minSize=(50,50))

print("Detected Faces: ", len(detectedFaces))
print("Bounding Boxs:")
print("LEFT, TOP, WIDTH, HEIGHT:")
print(detectedFaces)

for (x, y, l, a) in detectedFaces:
    cv2.rectangle(NOCamouflage, (x, y), (x + l, y + a), (0, 255, 0), 2)

plt.imshow(NOCamouflage)
plt.show()

grayImage2 = cv2.cvtColor(Camouflage, cv2.COLOR_BGR2GRAY)
detectedFaces = classifier.detectMultiScale(grayImage2, scaleFactor=1.2, minSize=(50,50))

print("Detected Faces: ", len(detectedFaces))
print("Bounding Boxs:")
print("LEFT, TOP, WIDTH, HEIGHT:")
print(detectedFaces)

for (x, y, l, a) in detectedFaces:
    cv2.rectangle(Camouflage, (x, y), (x + l, y + a), (0, 255, 0), 2)

plt.imshow(Camouflage)
plt.show()
# Out:
# Detected Faces:  1
# Bounding Boxs:
# LEFT, TOP, WIDTH, HEIGHT:
# [[111  48  87  87]]
# Detected Faces:  0
# Bounding Boxs:
# LEFT, TOP, WIDTH, HEIGHT:
# ()

# %% [markdown]
# The Haar Cascade tends to present false positives. Some patterns may mislead this technique as can be seen below:

# %%
import cv2
from matplotlib import pyplot as plt

frame = cv2.imread("gdrive/My Drive/Colab Notebooks/face_detection/photos/ra,unisex_tshirt,x2200,fafafa:ca443f4786,front-c,392,146,750,1000-bg,f8f8f8.u1.jpg")
image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

classifier= cv2.CascadeClassifier("gdrive/My Drive/Colab Notebooks/face_detection/resources/haarcascade_frontalface_default.xml")

grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detectedFaces = classifier.detectMultiScale(grayImage, scaleFactor=1.2, minSize=(50,50))

print("Detected Faces: ", len(detectedFaces))
print("Bounding Boxs:")
print("LEFT, TOP, WIDTH, HEIGHT:")
print(detectedFaces)

for (x, y, l, a) in detectedFaces:
    cv2.rectangle(image, (x, y), (x + l, y + a), (0, 255, 0), 2)

plt.imshow(image)
plt.show()
# Out:
# Detected Faces:  16
# Bounding Boxs:
# LEFT, TOP, WIDTH, HEIGHT:
# [[263  91 190 190]
#  [254 416  50  50]
#  [459 426  53  53]
#  [345 448  60  60]
#  [415 457  60  60]
#  [300 496  51  51]
#  [258 518  52  52]
#  [434 565  50  50]
#  [254 599  50  50]
#  [459 610  53  53]
#  [362 551  86  86]
#  [413 640  61  61]
#  [256 702  53  53]
#  [298 680  52  52]
#  [343 630  64  64]
#  [382 698  76  76]]
